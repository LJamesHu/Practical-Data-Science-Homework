# %% [markdown]
# # Take Home Assessment 1 - PDS Fall 2013

# %% [markdown]
# <b>Instructions</b>
#
# You should use Python to answer all parts of this question, unless specifically indicated otherwise.
#
# You should write one Python script or notebook that clearly labels where each part of the problem is addressed.  The script should run for us and produce any requested output.
#
# If you’re not using an ipython notebook, You should turn in the Python script and an accompanying pdf document that presents any answers to questions, as well as parts of your solution that are not contained in the script (for example, a sorted list, a plot, etc.).
#
# Your data for this exercise are in data file [assess1_data.json](http://stern.nyu.edu/~ja1517/data/assess1_data.json).  These data are a subset of data from a targeted marketing campaign.  The original data have hundreds of fields and hundreds of thousands of records; some other changes have been made as well.  Each data record describes a targeted consumer by various attributes.
# * * *
# Follow all directions and answer all questions.  Be concise and precise
#
# in your answers:
# * * *

# %%
# !wget http://stern.nyu.edu/~ja1517/data/assess1_data.json

# %% [markdown]
# Cannot get wget to work. Downloaded manually.

# %% [markdown]
# <b>a) What is the structure of the file?  What are the attributes/fields? How many customers are there?  (Can be answered easily at the command line, without Python.)</b>

# %% [markdown]
# <code>{"RFA_2F":4,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":7.4814814815,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":3.33,"INCOME":3,"FISTDATE":9001,"NAME":"Reshama Y. Saat"}</code>

# %% [markdown]
# So overall, the file is a json. It has a wide variety of fields: RFA_2F, RFA_2A, TARGET_B, LASTGIFT, AVGGIFT, PEPSTRFL, LASTDATE, WEALTH_INDEX, INCOME, FISTDATE, NAME.

# %%
# !wc -l assess1_data.json
# Out:
# 35275 assess1_data.json

# %% [markdown]
# <b>b) Read in the datafile into a Python program.  Do any two customers have the same name?  If so, list the duplicated name(s).</b>

# %%
# Import json reader
import json

# Used for Question b
# Count names to see if there are any duplicate names
names = {}
dupnames = {}

# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:

    	# --------------------------------------

    	# Used for Question b

    	# Used to count names, if not counted, instantiate in names
    	if names.get(json.loads(line)["NAME"]) == None:
			names[json.loads(line)["NAME"]] = 1
        # If it is not None, then the name has already been counted, which means that the name is a duplicate
        else:
            dupnames[json.loads(line)["NAME"]] = 1

        # --------------------------------------

# --------------------------------------

# Question b

# Print out the duplicate names
print dupnames.keys()

# --------------------------------------
# Out:
# [u"Sneha K. O'Hooper"]

# %% [markdown]
# <b>c) Sometimes data values are missing and programs in the data processing pipeline fill in special values that can screw up analysis. How many rows have value -9999?  Do not consider them in any further processing.</b>

# %%
# Import json reader
import json

# Used for Question c
# Counter for instances of missing data
missingdata = 0
# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:
        
        # --------------------------------------

        # Used for Question c
        # If it has -9999 fields
        if line.find("-9999") != -1:
            # Count number of -9999 fields
            missingdata += 1
            
        # --------------------------------------
        
# --------------------------------------

# Question c

# Print number of -9999 fields
print missingdata

# --------------------------------------
# Out:
# 3

# %% [markdown]
# <b>d) RFA_2F and RFA_2A are marketing codes summarizing the recency and frequency of historical customer response.  What values do they take and what is the frequency of each value in the data?  What values does WEALTH_INDEX take?</b>

# %%
# Import json reader
import json

# Used for Question c
# Counter for instances of missing data
missingdata = 0

# Used for Question d
# Dictionaries to get values and frequency
RFA2F = {}
RFA2A = {}

# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:

        # --------------------------------------

        # Used for Question c
        # If it has -9999 fields
        if line.find("-9999") != -1:
            # Count number of -9999 fields
            missingdata += 1

        # Otherwise given no -9999 fields
        else:
            # --------------------------------------

            # Used for Question d

            # Used to count RFA_2F values, if not counted, instantiate in RFA2F
            if RFA2F.get(json.loads(line)["RFA_2F"]) == None:
                RFA2F[json.loads(line)["RFA_2F"]] = 1
            # Otherwise if already in, just increment existing key by 1
            else:
                RFA2F[json.loads(line)["RFA_2F"]] += 1

            # Used to count RFA_2A values, if not counted, instantiate in RFA2A
            if RFA2A.get(json.loads(line)["RFA_2A"]) == None:
                RFA2A[json.loads(line)["RFA_2A"]] = 1
            # Otherwise if already in, just increment existing key by 1
            else:
                RFA2A[json.loads(line)["RFA_2A"]] += 1

            # --------------------------------------
    
# --------------------------------------

# Question d

# Print values and frequency of RFA_2F
print RFA2F

# Print values and frequency of RFA_2A
print RFA2A

# --------------------------------------
# Out:
# {1: 12530, 2: 8134, 3: 7367, 4: 7241}
# {u'E': 12884, u'D': 5074, u'G': 5125, u'F': 12189}

# %% [markdown]
# <b>e) TARGET_B describes whether this customer responded (1) or did not respond (0) to the campaign.  What proportion of the targeted consumers responded?</b>

# %%
# Import json reader
import json

# Used for Question c
# Counter for instances of missing data
missingdata = 0

# Used for Question e
# Dictionary to get values and frequency
TARGETB = {0:0, 1:0}

# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:

        # --------------------------------------

        # Used for Question c
        # If it has -9999 fields
        if line.find("-9999") != -1:
            # Count number of -9999 fields
            missingdata += 1

        # Otherwise given no -9999 fields
        else:
            # --------------------------------------

            # Used for Question e

            # Otherwise if already in, just increment existing key by 1
            TARGETB[json.loads(line)["TARGET_B"]] += 1

            # --------------------------------------

# --------------------------------------

# Question e

# Print values and frequency of TARGET_B
print TARGETB

# Print proportion of targeted consumers that responded
print TARGETB[1]/float(TARGETB[0]+TARGETB[1])

# --------------------------------------
# Out:
# {0: 33046, 1: 2226}
# 0.0631095486505

# %% [markdown]
# <b>f) Is there a difference in the distribution of the WEALTH_INDEX for the responders from the non-responders?  Explain.</b>

# %%
# Show histogram distribution in notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Import json reader
import json
# Import numpy for mean/standard deviation
import numpy as np
# Import pyplot for plotting
import matplotlib.pyplot as plt

# Used for Question c
# Counter for instances of missing data
missingdata = 0

# Used for Question f, g
# Array of Wealth given response
Wealth0 = []
Wealth1 = []

# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:

    	# --------------------------------------

        # Used for Question c
        # If it has -9999 fields
        if line.find("-9999") != -1:
            # Count number of -9999 fields
            missingdata += 1

        # Otherwise given no -9999 fields
        else:
            # --------------------------------------

            # Used for Question f, g

            # If the person did not respond
            if json.loads(line)["TARGET_B"] == 0:
                # Add their wealth index to the nonresponders wealth array
                Wealth0.append(json.loads(line)["WEALTH_INDEX"])
            # Otherwise they did
            else:
                # Add their wealth index to the responders wealth array
                Wealth1.append(json.loads(line)["WEALTH_INDEX"])

            # --------------------------------------

# --------------------------------------

# Question f

# Show the mean and standard deviations as measure of distribution
print "Wealth Index Given No Response"
print "The average customer's wealth index given no response is " + str(np.mean(Wealth0))
print "The standard deviation of a customer's wealth index given no response is " + str(np.std(Wealth0))

# Plot out the distribution histogram of a customer's wealth index given no response
fig0, axes0 = plt.subplots()

axes0.hist(Wealth0, bins = 20)
axes0.set_xlabel('Wealth Index')
axes0.set_ylabel('Number of Customers')
axes0.set_title('Wealth Index Given No Response');
plt.show()

print "========================"

# Show the mean and standard deviations as measure of distribution
print "Wealth Index Given Response"
print "The average customer's wealth index given response is " + str(np.mean(Wealth1))
print "The standard deviation of a customer's wealth index given response is " + str(np.std(Wealth1))

# Plot out the distribution histogram of a customer's wealth index given response
fig1, axes1 = plt.subplots()

axes1.hist(Wealth1, bins = 20)
axes1.set_xlabel('Wealth Index')
axes1.set_ylabel('Number of Customers')
axes1.set_title('Wealth Index Given Response');
plt.show()

# --------------------------------------
# Out:
# Wealth Index Given No Response
# The average customer's wealth index given no response is 4.49830932639
# The standard deviation of a customer's wealth index given no response is 5.82521634181
# ========================
# Wealth Index Given Response
# The average customer's wealth index given response is 20.2576010782
# The standard deviation of a customer's wealth index given response is 26.7866938611

# %% [markdown]
# As can be seen from the different means, standard deviations and distributions, the wealth index is higher if they responded and more distributed over higher wealth indexes than if they did not respond.

# %% [markdown]
# <b>g) Plot the distributions of WEALTH_INDEX for the responders and non-responders on one graph to show the similarities and differences. Use a histogram.  What is the difference in the graphs from plotting percents versus counts on the y-axis?  (Hint: in the matplotlib "hist", look at "normed=True" and look at different numbers of "bins".)</b>

# %% [markdown]
# Using the data from before:

# %%
# --------------------------------------

# Question g

# Plot out the distribution histogram of a customer's wealth index
figboth, axesboth = plt.subplots()

axesboth.hist([Wealth0, Wealth1], bins = 20)
axesboth.set_xlabel('Wealth Index')
axesboth.set_ylabel('Number of Customers')
axesboth.set_title('Wealth Index of Customers');
plt.show()

# Plot out the distribution histogram of a customer's wealth index
figboth2, axesboth2 = plt.subplots()

axesboth2.hist([Wealth0, Wealth1], bins = 20, normed = True)
axesboth2.set_xlabel('Wealth Index')
axesboth2.set_ylabel('Number of Customers %')
axesboth2.set_title('Wealth Index of Customers %');
plt.show()

# --------------------------------------

# %% [markdown]
# Adding <code>normmed = True</code> creates a more accurate idea of the results as showing the pure counts, the customers who responded are in the significant minority thus its better represented by percentages than by pure counts

# %% [markdown]
# <b>h) Alphabetize the records by the NAME field.  Number them from 1 at the beginning of the alphabet.  Do not print them all out.  Just print out alphabetized records 1-10 and alphabetized records 20,000-20,010.</b>

# %%
# Import json reader
import json
# Import numpy for mean/standard deviation
import numpy as np
# Import pyplot for plotting
import matplotlib.pyplot as plt

# Used for Question c
# Counter for instances of missing data
missingdata = 0

# Used for Question h, i, j
# Array to be manipulated to display records by name field
RecordsList = []

# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:

    	# --------------------------------------

        # Used for Question c
        # If it has -9999 fields
        if line.find("-9999") != -1:
            # Count number of -9999 fields
            missingdata += 1

        # Otherwise given no -9999 fields
        else:
            # --------------------------------------

            # Used for question h, i, j

            # Add line to array to be sorted later
            RecordsList.append(line)

            # --------------------------------------

# --------------------------------------

# Question h

# Used sorted to organize list of records by NAME field. Display results 0 - 10.
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"])[0:10]

# Display results 20,000 - 20,010
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"])[20000:20010]

# --------------------------------------
# Out:
# ['{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":9.3541666667,"PEPSTRFL":"X","LASTDATE":9612,"WEALTH_INDEX":2.52,"INCOME":5,"FISTDATE":9104,"NAME":"Abby A. Bhandari"}\n', '{"RFA_2F":4,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":7,"AVGGIFT":7.4615384615,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.20,"INCOME":7,"FISTDATE":9401,"NAME":"Abby A. Casagrande Sr."}\n', '{"RFA_2F":3,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":16.066666667,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.27,"INCOME":4,"FISTDATE":8612,"NAME":"Abby A. Cedrone"}\n', '{"RFA_2F":4,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":13.1,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":2.24,"INCOME":5,"FISTDATE":9110,"NAME":"Abby A. Choi"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":10,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":6.45,"INCOME":7,"FISTDATE":9503,"NAME":"Abby A. Cohodes"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8.25,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":4.69,"INCOME":1,"FISTDATE":8612,"NAME":"Abby A. Feng Jr."}\n', '{"RFA_2F":3,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":7,"AVGGIFT":4.4090909091,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":3.25,"INCOME":6,"FISTDATE":9004,"NAME":"Abby A. George"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":11,"AVGGIFT":9,"PEPSTRFL":"X","LASTDATE":9509,"WEALTH_INDEX":4.54,"INCOME":2,"FISTDATE":8608,"NAME":"Abby A. Harchwani"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":15,"AVGGIFT":10.142857143,"PEPSTRFL":"X","LASTDATE":9508,"WEALTH_INDEX":1.58,"INCOME":3,"FISTDATE":9402,"NAME":"Abby A. Ho"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8.1666666667,"PEPSTRFL":"X","LASTDATE":9511,"WEALTH_INDEX":3.91,"INCOME":5,"FISTDATE":9409,"NAME":"Abby A. Hooper"}\n']
# ['{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.875,"PEPSTRFL":"X","LASTDATE":9506,"WEALTH_INDEX":3.71,"INCOME":4,"FISTDATE":8909,"NAME":"Kelly G. Zhu Jr."}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":16,"AVGGIFT":10.5,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":1.08,"INCOME":7,"FISTDATE":8701,"NAME":"Kelly George Jr."}\n', '{"RFA_2F":4,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":5.4736842105,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":0.93,"INCOME":4,"FISTDATE":9010,"NAME":"Kelly Goldston III"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":9.8518518519,"PEPSTRFL":"X","LASTDATE":9507,"WEALTH_INDEX":3.93,"INCOME":7,"FISTDATE":8702,"NAME":"Kelly H. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":13,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":1.67,"INCOME":6,"FISTDATE":9501,"NAME":"Kelly H. Aiyangar III"}\n', '{"RFA_2F":4,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":25,"AVGGIFT":18,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":2.23,"INCOME":5,"FISTDATE":9406,"NAME":"Kelly H. Cedrone"}\n', '{"RFA_2F":1,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":33,"AVGGIFT":25.4,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":8.43,"INCOME":5,"FISTDATE":8802,"NAME":"Kelly H. Cohodes"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":10,"AVGGIFT":11.5,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":7.57,"INCOME":2,"FISTDATE":8612,"NAME":"Kelly H. Doban"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":15,"AVGGIFT":9.3,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":2.41,"INCOME":1,"FISTDATE":9101,"NAME":"Kelly H. George"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":6.2352941176,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":3.20,"INCOME":2,"FISTDATE":8609,"NAME":"Kelly H. Hao Sr."}\n']

# %% [markdown]
# <b>i) Redo part (h), except alphabetize by the individual's *last name*.</b>

# %%
# --------------------------------------

# Question i

# Used sorted to organize list of records by NAME field, which is then split to grab the last name. Display results 0 - 10.
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"].split()[-1])[0:10]

# Display results 20,000 - 20,010
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"].split()[-1])[20000:20010]

# --------------------------------------
# Out:
# ['{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":22,"AVGGIFT":18.090909091,"PEPSTRFL":"X","LASTDATE":9507,"WEALTH_INDEX":2.19,"INCOME":3,"FISTDATE":8801,"NAME":"Jianping C. Aiyangar"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8.5,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":13.00,"INCOME":7,"FISTDATE":9103,"NAME":"Ann R. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":14.30,"INCOME":4,"FISTDATE":9409,"NAME":"Sonal O. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.1578947368,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":1.64,"INCOME":7,"FISTDATE":8902,"NAME":"Deepa K. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":4.5882352941,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":7.59,"INCOME":5,"FISTDATE":9002,"NAME":"Xias A. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":19,"AVGGIFT":16.230769231,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":4.11,"INCOME":5,"FISTDATE":8909,"NAME":"Joseph R. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":12,"AVGGIFT":7.8,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":2.69,"INCOME":2,"FISTDATE":8904,"NAME":"Abby E. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":25,"AVGGIFT":20,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":2.58,"INCOME":7,"FISTDATE":8610,"NAME":"Antik O. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":17.5,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":3.36,"INCOME":6,"FISTDATE":9309,"NAME":"Craig P. Aiyangar"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":10.4,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":5.28,"INCOME":5,"FISTDATE":9110,"NAME":"Jaesik N. Aiyangar"}\n']
# ['{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":14,"PEPSTRFL":"X","LASTDATE":9509,"WEALTH_INDEX":5.21,"INCOME":3,"FISTDATE":9109,"NAME":"Shenglun Z. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":10,"AVGGIFT":9.5454545455,"PEPSTRFL":"X","LASTDATE":9508,"WEALTH_INDEX":26.25,"INCOME":4,"FISTDATE":9001,"NAME":"Antik I. McSanchez"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":12,"AVGGIFT":12.5,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":6.79,"INCOME":5,"FISTDATE":9101,"NAME":"Amrish A. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":15.7,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":2.31,"INCOME":6,"FISTDATE":9106,"NAME":"Liwen K. McSanchez"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":15,"AVGGIFT":10.625,"PEPSTRFL":"X","LASTDATE":9510,"WEALTH_INDEX":8.94,"INCOME":4,"FISTDATE":9310,"NAME":"Corinne C. McSanchez"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.275862069,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.93,"INCOME":1,"FISTDATE":8610,"NAME":"Vamsee G. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":3.4615384615,"PEPSTRFL":"X","LASTDATE":9510,"WEALTH_INDEX":2.52,"INCOME":2,"FISTDATE":8608,"NAME":"Abhishek N. McSanchez"}\n', '{"RFA_2F":3,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":16.685714286,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":1.87,"INCOME":5,"FISTDATE":8703,"NAME":"Smriti K. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.6,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":4.11,"INCOME":5,"FISTDATE":8901,"NAME":"Sonal G. McSanchez"}\n', '{"RFA_2F":4,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":4.8333333333,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.39,"INCOME":5,"FISTDATE":9409,"NAME":"Zelos Q. McSanchez"}\n']

# %% [markdown]
# <b>j) Data such as this are used to evaluate predictive models. Consider predicting response with the following quantity: -40 + 0.8*WEALTH_INDEX + 0.12*RFA_2F
#
# Print the top-10 customer records, ordered by this quantity.  Include the value of this quantity.</b>

# %%
# --------------------------------------

# Question j

# Used sorted to organize list of records by the predictive model field
PredictiveModel = sorted(RecordsList, key=lambda name: -40 + 0.8*json.loads(name)["WEALTH_INDEX"] + 0.12*json.loads(name)["RFA_2F"], reverse = True)

# Create a lambada through which the model can take a value
Model = lambda x: -40 + 0.8*json.loads(PredictiveModel[x])["WEALTH_INDEX"] + 0.12*json.loads(PredictiveModel[x])["RFA_2F"]

# Use a for loop the print the top 10 consumer records and their score from the predictive model
for record in range(0,10):
    print PredictiveModel[record] + str(Model(record))

# --------------------------------------
# Out:
# {"RFA_2F":4,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":13,"AVGGIFT":9.75,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":99.85,"INCOME":5,"FISTDATE":9301,"NAME":"Kevin E. Zaczynski"}
# 40.36
# {"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":7,"AVGGIFT":7.9333333333,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":99.83,"INCOME":1,"FISTDATE":9001,"NAME":"Kevin J. Sanchez"}
# 40.104
# {"RFA_2F":1,"RFA_2A":"G","TARGET_B":1,"LASTGIFT":38,"AVGGIFT":27.277777778,"PEPSTRFL":"X","LASTDATE":9504,"WEALTH_INDEX":99.08,"INCOME":2,"FISTDATE":8707,"NAME":"Joseph I. Shaikh"}
# 39.384
# {"RFA_2F":4,"RFA_2A":"D","TARGET_B":1,"LASTGIFT":5,"AVGGIFT":4.25,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":98.60,"INCOME":2,"FISTDATE":8702,"NAME":"Corinne D. Doban III"}
# 39.36
# {"RFA_2F":1,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":10,"AVGGIFT":10.25,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":98.97,"INCOME":5,"FISTDATE":9009,"NAME":"Douglas G. Kim Jr."}
# 39.296
# {"RFA_2F":1,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":11,"AVGGIFT":7.5454545455,"PEPSTRFL":"X","LASTDATE":9508,"WEALTH_INDEX":98.71,"INCOME":5,"FISTDATE":8609,"NAME":"Tyler X. Kim Sr."}
# 39.088
# {"RFA_2F":4,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":10.681818182,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":98.25,"INCOME":4,"FISTDATE":9103,"NAME":"Vitalii U. Hill"}
# 39.08
# {"RFA_2F":3,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":3,"AVGGIFT":2.7096774194,"PEPSTRFL":"X","LASTDATE":9511,"WEALTH_INDEX":98.35,"INCOME":1,"FISTDATE":8608,"NAME":"Zhengyang E. McSanchez"}
# 39.04
# {"RFA_2F":1,"RFA_2A":"F","TARGET_B":1,"LASTGIFT":15,"AVGGIFT":9.5294117647,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":98.59,"INCOME":5,"FISTDATE":8702,"NAME":"Douglas Q. Goldston"}
# 38.992
# {"RFA_2F":1,"RFA_2A":"F","TARGET_B":1,"LASTGIFT":15,"AVGGIFT":9.1666666667,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":98.36,"INCOME":5,"FISTDATE":9103,"NAME":"Ryan E. Singh"}
# 38.808

# %% [markdown]
# <b>k) OPTIONAL (will not affect assessment): Suppose we had a budget to target only 10% of consumers. Can these data help us to understand whether the "predictive model" of part (j) would be helpful? How? (Is it helpful?)</b>

# %% [markdown]
# Yes and no. While it has some usefulness, the top 10 results and the function indicates that its basically all correlated to the individual's wealth index. The factor in the model has virtually no effect with an effect between .12 and .48. Whereas wealth index can drive the model from 0 to 80. Wealth index can drive the model almost 200x more than the RFA_2F factor can.
#
# An observation is that rich people have a higher likelihood to give, which can be seen from the histograms from before, but the model itself is so broad that it can't specifically target any meaningful factors beyond wealth index. In addition, it would not help capture the significant amount of individuals that are along the lower end of the wealth index spectrum that donate.

# %% [markdown]
# ## Full Code

# %%
# Import json reader
import json
# Import numpy for mean/standard deviation
import numpy as np
# Import pyplot for plotting
import matplotlib.pyplot as plt

# Used for Question b
# Count names to see if there are any duplicate names
names = {}
dupnames = {}

# Used for Question c
# Counter for instances of missing data
missingdata = 0

# Used for Question d
# Dictionaries to get values and frequency
RFA2F = {}
RFA2A = {}

# Used for Question e
# Dictionary to get values and frequency
TARGETB = {0:0, 1:0}

# Used for Question f, g
# Array of Wealth given response
Wealth0 = []
Wealth1 = []

# Used for Question h, i, j
# Array to be manipulated to display records by name field
RecordsList = []

# --------------------------------------

# Open the file
with open("assess1_data.json") as f:
	# Iterate through every line of the file.
    for line in f:

    	# --------------------------------------

    	# Used for Question b

    	# Used to count names, if not counted, instantiate in names
    	if names.get(json.loads(line)["NAME"]) == None:
			names[json.loads(line)["NAME"]] = 1
        # If it is not None, then the name has already been counted, which means that the name is a duplicate
        else:
            dupnames[json.loads(line)["NAME"]] = 1

        # --------------------------------------

        # Used for Question c
        # If it has -9999 fields
        if line.find("-9999") != -1:
            # Count number of -9999 fields
            missingdata += 1

        # Otherwise given no -9999 fields
        else:
            # --------------------------------------

            # Used for Question d

            # Used to count RFA_2F values, if not counted, instantiate in RFA2F
            if RFA2F.get(json.loads(line)["RFA_2F"]) == None:
                RFA2F[json.loads(line)["RFA_2F"]] = 1
            # Otherwise if already in, just increment existing key by 1
            else:
                RFA2F[json.loads(line)["RFA_2F"]] += 1

            # Used to count RFA_2A values, if not counted, instantiate in RFA2A
            if RFA2A.get(json.loads(line)["RFA_2A"]) == None:
                RFA2A[json.loads(line)["RFA_2A"]] = 1
            # Otherwise if already in, just increment existing key by 1
            else:
                RFA2A[json.loads(line)["RFA_2A"]] += 1

            # --------------------------------------

            # Used for Question e

            # Otherwise if already in, just increment existing key by 1
            TARGETB[json.loads(line)["TARGET_B"]] += 1

            # --------------------------------------

            # Used for Question f, g

            # If the person did not respond
            if json.loads(line)["TARGET_B"] == 0:
                # Add their wealth index to the nonresponders wealth array
                Wealth0.append(json.loads(line)["WEALTH_INDEX"])
            # Otherwise they did
            else:
                # Add their wealth index to the responders wealth array
                Wealth1.append(json.loads(line)["WEALTH_INDEX"])

            # --------------------------------------

            # Used for question h, i, j

            # Add line to array to be sorted later
            RecordsList.append(line)

            # --------------------------------------

# --------------------------------------

# Question b

# Print out the duplicate names
print dupnames.keys()

# --------------------------------------

# Question c

# Print number of -9999 fields
print missingdata

# --------------------------------------

# Question d

# Print values and frequency of RFA_2F
print RFA2F

# Print values and frequency of RFA_2A
print RFA2A

# --------------------------------------

# Question e

# Print values and frequency of TARGET_B
print TARGETB

# Print proportion of targeted consumers that responded
print TARGETB[1]/float(TARGETB[0]+TARGETB[1])

# --------------------------------------

# Question f

# Show the mean and standard deviations as measure of distribution
print "Wealth Index Given No Response"
print "The average customer's wealth index given no response is " + str(np.mean(Wealth0))
print "The standard deviation of a customer's wealth index given no response is " + str(np.std(Wealth0))

# Plot out the distribution histogram of a customer's wealth index given no response
fig0, axes0 = plt.subplots()

axes0.hist(Wealth0, bins = 20)
axes0.set_xlabel('Wealth Index')
axes0.set_ylabel('Number of Customers')
axes0.set_title('Wealth Index Given No Response');
plt.show()

print "========================"

# Show the mean and standard deviations as measure of distribution
print "Wealth Index Given Response"
print "The average customer's wealth index given response is " + str(np.mean(Wealth1))
print "The standard deviation of a customer's wealth index given response is " + str(np.std(Wealth1))

# Plot out the distribution histogram of a customer's wealth index given response
fig1, axes1 = plt.subplots()

axes1.hist(Wealth1, bins = 20)
axes1.set_xlabel('Wealth Index')
axes1.set_ylabel('Number of Customers')
axes1.set_title('Wealth Index Given Response');
plt.show()

# --------------------------------------

# Question g

# Plot out the distribution histogram of a customer's wealth index
figboth, axesboth = plt.subplots()

axesboth.hist([Wealth0, Wealth1], bins = 20)
axesboth.set_xlabel('Wealth Index')
axesboth.set_ylabel('Number of Customers')
axesboth.set_title('Wealth Index of Customers');
plt.show()

# Plot out the distribution histogram of a customer's wealth index
figboth2, axesboth2 = plt.subplots()

axesboth2.hist([Wealth0, Wealth1], bins = 20, normed = True)
axesboth2.set_xlabel('Wealth Index')
axesboth2.set_ylabel('Number of Customers %')
axesboth2.set_title('Wealth Index of Customers %');
plt.show()

# --------------------------------------

# Question h

# Used sorted to organize list of records by NAME field. Display results 0 - 10.
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"])[0:10]

# Display results 20,000 - 20,010
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"])[20000:20010]

# --------------------------------------

# Question i

# Used sorted to organize list of records by NAME field, which is then split to grab the last name. Display results 0 - 10.
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"].split()[-1])[0:10]

# Display results 20,000 - 20,010
print sorted(RecordsList, key=lambda name: json.loads(name)["NAME"].split()[-1])[20000:20010]

# --------------------------------------

# Question j

# Used sorted to organize list of records by the predictive model field
PredictiveModel = sorted(RecordsList, key=lambda name: -40 + 0.8*json.loads(name)["WEALTH_INDEX"] + 0.12*json.loads(name)["RFA_2F"], reverse = True)

# Create a lambada through which the model can take a value
Model = lambda x: -40 + 0.8*json.loads(PredictiveModel[x])["WEALTH_INDEX"] + 0.12*json.loads(PredictiveModel[x])["RFA_2F"]

# Use a for loop the print the top 10 consumer records and their score from the predictive model
for record in range(0,10):
    print PredictiveModel[record] + str(Model(record))

# --------------------------------------
# Out:
# [u"Sneha K. O'Hooper"]
# 3
# {1: 12530, 2: 8134, 3: 7367, 4: 7241}
# {u'E': 12884, u'D': 5074, u'G': 5125, u'F': 12189}
# {0: 33046, 1: 2226}
# 0.0631095486505
# Wealth Index Given No Response
# The average customer's wealth index given no response is 4.49830932639
# The standard deviation of a customer's wealth index given no response is 5.82521634181
# ========================
# Wealth Index Given Response
# The average customer's wealth index given response is 20.2576010782
# The standard deviation of a customer's wealth index given response is 26.7866938611
# ['{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":9.3541666667,"PEPSTRFL":"X","LASTDATE":9612,"WEALTH_INDEX":2.52,"INCOME":5,"FISTDATE":9104,"NAME":"Abby A. Bhandari"}\n', '{"RFA_2F":4,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":7,"AVGGIFT":7.4615384615,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.20,"INCOME":7,"FISTDATE":9401,"NAME":"Abby A. Casagrande Sr."}\n', '{"RFA_2F":3,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":16.066666667,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.27,"INCOME":4,"FISTDATE":8612,"NAME":"Abby A. Cedrone"}\n', '{"RFA_2F":4,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":13.1,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":2.24,"INCOME":5,"FISTDATE":9110,"NAME":"Abby A. Choi"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":10,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":6.45,"INCOME":7,"FISTDATE":9503,"NAME":"Abby A. Cohodes"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8.25,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":4.69,"INCOME":1,"FISTDATE":8612,"NAME":"Abby A. Feng Jr."}\n', '{"RFA_2F":3,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":7,"AVGGIFT":4.4090909091,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":3.25,"INCOME":6,"FISTDATE":9004,"NAME":"Abby A. George"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":11,"AVGGIFT":9,"PEPSTRFL":"X","LASTDATE":9509,"WEALTH_INDEX":4.54,"INCOME":2,"FISTDATE":8608,"NAME":"Abby A. Harchwani"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":15,"AVGGIFT":10.142857143,"PEPSTRFL":"X","LASTDATE":9508,"WEALTH_INDEX":1.58,"INCOME":3,"FISTDATE":9402,"NAME":"Abby A. Ho"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8.1666666667,"PEPSTRFL":"X","LASTDATE":9511,"WEALTH_INDEX":3.91,"INCOME":5,"FISTDATE":9409,"NAME":"Abby A. Hooper"}\n']
# ['{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.875,"PEPSTRFL":"X","LASTDATE":9506,"WEALTH_INDEX":3.71,"INCOME":4,"FISTDATE":8909,"NAME":"Kelly G. Zhu Jr."}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":16,"AVGGIFT":10.5,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":1.08,"INCOME":7,"FISTDATE":8701,"NAME":"Kelly George Jr."}\n', '{"RFA_2F":4,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":5.4736842105,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":0.93,"INCOME":4,"FISTDATE":9010,"NAME":"Kelly Goldston III"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":9.8518518519,"PEPSTRFL":"X","LASTDATE":9507,"WEALTH_INDEX":3.93,"INCOME":7,"FISTDATE":8702,"NAME":"Kelly H. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":13,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":1.67,"INCOME":6,"FISTDATE":9501,"NAME":"Kelly H. Aiyangar III"}\n', '{"RFA_2F":4,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":25,"AVGGIFT":18,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":2.23,"INCOME":5,"FISTDATE":9406,"NAME":"Kelly H. Cedrone"}\n', '{"RFA_2F":1,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":33,"AVGGIFT":25.4,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":8.43,"INCOME":5,"FISTDATE":8802,"NAME":"Kelly H. Cohodes"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":10,"AVGGIFT":11.5,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":7.57,"INCOME":2,"FISTDATE":8612,"NAME":"Kelly H. Doban"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":15,"AVGGIFT":9.3,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":2.41,"INCOME":1,"FISTDATE":9101,"NAME":"Kelly H. George"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":6.2352941176,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":3.20,"INCOME":2,"FISTDATE":8609,"NAME":"Kelly H. Hao Sr."}\n']
# ['{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":22,"AVGGIFT":18.090909091,"PEPSTRFL":"X","LASTDATE":9507,"WEALTH_INDEX":2.19,"INCOME":3,"FISTDATE":8801,"NAME":"Jianping C. Aiyangar"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8.5,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":13.00,"INCOME":7,"FISTDATE":9103,"NAME":"Ann R. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":8,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":14.30,"INCOME":4,"FISTDATE":9409,"NAME":"Sonal O. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.1578947368,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":1.64,"INCOME":7,"FISTDATE":8902,"NAME":"Deepa K. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":4.5882352941,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":7.59,"INCOME":5,"FISTDATE":9002,"NAME":"Xias A. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":19,"AVGGIFT":16.230769231,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":4.11,"INCOME":5,"FISTDATE":8909,"NAME":"Joseph R. Aiyangar"}\n', '{"RFA_2F":3,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":12,"AVGGIFT":7.8,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":2.69,"INCOME":2,"FISTDATE":8904,"NAME":"Abby E. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":25,"AVGGIFT":20,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":2.58,"INCOME":7,"FISTDATE":8610,"NAME":"Antik O. Aiyangar"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":17.5,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":3.36,"INCOME":6,"FISTDATE":9309,"NAME":"Craig P. Aiyangar"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":10.4,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":5.28,"INCOME":5,"FISTDATE":9110,"NAME":"Jaesik N. Aiyangar"}\n']
# ['{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":14,"PEPSTRFL":"X","LASTDATE":9509,"WEALTH_INDEX":5.21,"INCOME":3,"FISTDATE":9109,"NAME":"Shenglun Z. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":10,"AVGGIFT":9.5454545455,"PEPSTRFL":"X","LASTDATE":9508,"WEALTH_INDEX":26.25,"INCOME":4,"FISTDATE":9001,"NAME":"Antik I. McSanchez"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":12,"AVGGIFT":12.5,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":6.79,"INCOME":5,"FISTDATE":9101,"NAME":"Amrish A. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":15.7,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":2.31,"INCOME":6,"FISTDATE":9106,"NAME":"Liwen K. McSanchez"}\n', '{"RFA_2F":1,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":15,"AVGGIFT":10.625,"PEPSTRFL":"X","LASTDATE":9510,"WEALTH_INDEX":8.94,"INCOME":4,"FISTDATE":9310,"NAME":"Corinne C. McSanchez"}\n', '{"RFA_2F":1,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.275862069,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.93,"INCOME":1,"FISTDATE":8610,"NAME":"Vamsee G. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":3.4615384615,"PEPSTRFL":"X","LASTDATE":9510,"WEALTH_INDEX":2.52,"INCOME":2,"FISTDATE":8608,"NAME":"Abhishek N. McSanchez"}\n', '{"RFA_2F":3,"RFA_2A":"G","TARGET_B":0,"LASTGIFT":20,"AVGGIFT":16.685714286,"PEPSTRFL":"X","LASTDATE":9603,"WEALTH_INDEX":1.87,"INCOME":5,"FISTDATE":8703,"NAME":"Smriti K. McSanchez"}\n', '{"RFA_2F":2,"RFA_2A":"F","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":7.6,"PEPSTRFL":"X","LASTDATE":9602,"WEALTH_INDEX":4.11,"INCOME":5,"FISTDATE":8901,"NAME":"Sonal G. McSanchez"}\n', '{"RFA_2F":4,"RFA_2A":"D","TARGET_B":0,"LASTGIFT":5,"AVGGIFT":4.8333333333,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":0.39,"INCOME":5,"FISTDATE":9409,"NAME":"Zelos Q. McSanchez"}\n']
# {"RFA_2F":4,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":13,"AVGGIFT":9.75,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":99.85,"INCOME":5,"FISTDATE":9301,"NAME":"Kevin E. Zaczynski"}
# 40.36
# {"RFA_2F":2,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":7,"AVGGIFT":7.9333333333,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":99.83,"INCOME":1,"FISTDATE":9001,"NAME":"Kevin J. Sanchez"}
# 40.104
# {"RFA_2F":1,"RFA_2A":"G","TARGET_B":1,"LASTGIFT":38,"AVGGIFT":27.277777778,"PEPSTRFL":"X","LASTDATE":9504,"WEALTH_INDEX":99.08,"INCOME":2,"FISTDATE":8707,"NAME":"Joseph I. Shaikh"}
# 39.384
# {"RFA_2F":4,"RFA_2A":"D","TARGET_B":1,"LASTGIFT":5,"AVGGIFT":4.25,"PEPSTRFL":"X","LASTDATE":9601,"WEALTH_INDEX":98.60,"INCOME":2,"FISTDATE":8702,"NAME":"Corinne D. Doban III"}
# 39.36
# {"RFA_2F":1,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":10,"AVGGIFT":10.25,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":98.97,"INCOME":5,"FISTDATE":9009,"NAME":"Douglas G. Kim Jr."}
# 39.296
# {"RFA_2F":1,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":11,"AVGGIFT":7.5454545455,"PEPSTRFL":"X","LASTDATE":9508,"WEALTH_INDEX":98.71,"INCOME":5,"FISTDATE":8609,"NAME":"Tyler X. Kim Sr."}
# 39.088
# {"RFA_2F":4,"RFA_2A":"E","TARGET_B":0,"LASTGIFT":10,"AVGGIFT":10.681818182,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":98.25,"INCOME":4,"FISTDATE":9103,"NAME":"Vitalii U. Hill"}
# 39.08
# {"RFA_2F":3,"RFA_2A":"E","TARGET_B":1,"LASTGIFT":3,"AVGGIFT":2.7096774194,"PEPSTRFL":"X","LASTDATE":9511,"WEALTH_INDEX":98.35,"INCOME":1,"FISTDATE":8608,"NAME":"Zhengyang E. McSanchez"}
# 39.04
# {"RFA_2F":1,"RFA_2A":"F","TARGET_B":1,"LASTGIFT":15,"AVGGIFT":9.5294117647,"PEPSTRFL":"X","LASTDATE":9505,"WEALTH_INDEX":98.59,"INCOME":5,"FISTDATE":8702,"NAME":"Douglas Q. Goldston"}
# 38.992
# {"RFA_2F":1,"RFA_2A":"F","TARGET_B":1,"LASTGIFT":15,"AVGGIFT":9.1666666667,"PEPSTRFL":"X","LASTDATE":9512,"WEALTH_INDEX":98.36,"INCOME":5,"FISTDATE":9103,"NAME":"Ryan E. Singh"}
# 38.808
